# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/vedantsuthar/Desktop/Superstore.csv',encoding='latin-1')

# %%
df.head(10)
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 5  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 7  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 9  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# ...

# %%
df1 = df[['Ship Mode','Segment','Customer Name','City','State','Category','Sub-Category','Sales','Profit','Region']]
df1
# Out:
#            Ship Mode    Segment     Customer Name             City  \
# 0       Second Class   Consumer       Claire Gute        Henderson
# 1       Second Class   Consumer       Claire Gute        Henderson
# 2       Second Class  Corporate   Darrin Van Huff      Los Angeles
# 3     Standard Class   Consumer    Sean O'Donnell  Fort Lauderdale
# 4     Standard Class   Consumer    Sean O'Donnell  Fort Lauderdale
# ...              ...        ...               ...              ...
# 9989    Second Class   Consumer  Tom Boeckenhauer            Miami
# 9990  Standard Class   Consumer       Dave Brooks       Costa Mesa
# 9991  Standard Class   Consumer       Dave Brooks       Costa Mesa
# 9992  Standard Class   Consumer       Dave Brooks       Costa Mesa
# 9993    Second Class   Consumer      Chris Cortes      Westminster
#
#            State         Category Sub-Category     Sales    Profit Region
# 0       Kentucky        Furniture    Bookcases  261.9600   41.9136  South
# ...

# %%
df2 = df[(df['Region'].isin(['West' , 'Centeral'] )) & (df['Segment']=='Consumer')&(df['Category'].isin(['Office Supplies','Furniture']))]
df2
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 5     CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 6     CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 8     CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 9     CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 10    CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# ...              ...         ...         ...             ...         ...
# 9943  CA-2014-143371  28-12-2014  03-01-2015  Standard Class    MD-17350
# 9959  CA-2017-137421  06-10-2017  11-10-2017  Standard Class    AJ-10945
# 9990  CA-2017-121258  26-02-2017  03-03-2017  Standard Class    DB-13060
# 9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class    DB-13060
# 9993  CA-2017-119914  04-05-2017  09-05-2017    Second Class    CC-12220
#
#         Customer Name   Segment        Country         City       State  \
# ...

# %%
df['Expanse'] = df['Sales'] - df['Profit']
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Profit Percentage'] = (df['Profit']/df['Expanse'])*100
df.sort_values(by=['Profit Percentage'], ascending=False, inplace=True)
df.head()
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 5561  CA-2017-133263  31-03-2017  02-04-2017    Second Class    JE-15610
# 5649  CA-2017-142342  17-07-2017  19-07-2017    Second Class    AJ-10795
# 1346  CA-2014-118339  17-03-2014  24-03-2014  Standard Class    BN-11515
# 4584  US-2017-163790  02-11-2017  04-11-2017    Second Class    NL-18310
# 4578  CA-2015-110947  09-06-2015  15-06-2015  Standard Class    AG-10765
#
#           Customer Name      Segment        Country          City       State  \
# 5561            Jim Epp    Corporate  United States       Atlanta     Georgia
# 5649    Anthony Johnson    Corporate  United States  Apple Valley  California
# 1346     Bradley Nguyen     Consumer  United States     Lakeville   Minnesota
# 4584     Nancy Lomonaco  Home Office  United States      Danville  California
# 4578  Anthony Garverick  Home Office  United States       Hampton    Virginia
#
# ...
