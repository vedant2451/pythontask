# %%
# Tuple
tuple1 = (10,12,12,4,2,4,3)
print(len(tuple1))
print(sum(tuple1))
print(max(tuple1))
print(min(tuple1))
# Out:
# 7
# 47
# 12
# 2

# %%
# indexing/slicing on tuple
tuple1[2]
tuple1[1:4]
tuple1.index(4)
tuple1.count(12)
# Out:
# 2
