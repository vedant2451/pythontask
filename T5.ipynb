# %%
# write code if value is not in list then add it and list element must be not more then 10
list1 = [25,89,45,14,56]

# %%
x = int(input("Enter a number: "))
y = len(list1)
if (x not in list1) and (y < 10) :
    list1.append(x)
else :
    print("List is full")
# Out:
# List is full
